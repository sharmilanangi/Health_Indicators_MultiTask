# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
vals = []
keys = []
  
 
# creating the bar plot
plt.bar(vals, keys,
        width = 0.4)
 
plt.xlabel("Courses offered")
plt.ylabel("No. of students enrolled")
plt.title("Students enrolled in different courses")
plt.show()

# %%
df = pd.DataFrame()

df["CMR"] = [0.21448048458813818, 0.22908786540963436]
df["BMI"] = [0.5185647842961669, 0.5731734444554782]
df["Setting"] = ["Single task", "Multi-task"]
df.set_index(["Setting"], inplace = True,
                    append = False, drop = True)
ax = df.plot.bar()
plt.xticks(rotation = 0)
plt.savefig('../filename.png', dpi=1000)

# %%
df = pd.DataFrame()

df["CMR"] = [0.20356427596200272, 0.21318189930419582, 0.22908786540963436, 0.230]
df["BMI"] = [0.4749747966266214, 0.5283810332264084, 0.5731734444554782, 0.579]
df["Dimensionality reduction method"] = ["Rand. proj.\n(512 dim)", "Rand. proj. \n(1024 dim)", "Rand. proj.\n (2048 dim)", "Top 500features"]
df.set_index(["Dimensionality reduction method"], inplace = True,
                    append = False, drop = True)
ax = df.plot.bar()
plt.xticks(rotation = 0)
plt.figure(dpi=1200)

# %%
df = pd.DataFrame()

df["BMI"] = [0.5110558628807051, 0.5414734950395524, 0.562, 0.5773752537447893, 0.5779753737384206]
df["BMI (single task)"] = [0.579] * 5
df["CMR"] = [0.22772862391262574 , 0.23147037313554228, 0.230, 0.2294438083585505, 0.2305272878726145]
df["CMR (single task)"] = [0.230] * 5
df["Loss weighting"] = ["0.9-0.1", "0.25-0.75", "0.5-0.5" ,"0.75-0.25", "0.1-0.9"]
styles = ["^-", "--","^-", "--"]

df.set_index(["Loss weighting"], inplace = True,
                    append = False, drop = True)
ax = df.plot(style=styles)
plt.xticks(rotation = 0)
plt.figure(dpi=2000)

# %%
df = pd.DataFrame()

df["Shallow heads"] =[0.2300, 0.562]
df["Deep heads"] = [0.19843205823958848, 0.5708436012790721]
df["Task"] = ["CMR", "BMI"]
df.set_index(["Task"], inplace = True,
                    append = False, drop = True)
ax = df.plot.bar()
plt.xticks(rotation = 0)
plt.figure(dpi=1200)
